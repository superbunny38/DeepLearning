# %% [markdown]
# <a href="https://colab.research.google.com/github/superbunny38/2021DeepLearning/blob/main/papers/PAGAN_getData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/LynnHo/PA-GAN-Tensorflow.git please
# Out:
# Cloning into 'please'...
# remote: Enumerating objects: 200, done.
# remote: Counting objects: 100% (200/200), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 200 (delta 87), reused 157 (delta 44), pack-reused 0
# Receiving objects: 100% (200/200), 2.30 MiB | 37.40 MiB/s, done.
# Resolving deltas: 100% (87/87), done.

# %%
# !ls
# Out:
# drive  please  sample_data

# %% [markdown]
# mount to google drive

# %%
!7z x /content/drive/MyDrive/2022/img_celeba.7z
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
# 1 folder, 14 files, 10191072466 bytes (9719 MiB)
#   0%
# Extracting archive: /content/drive/MyDrive/2022/img_celeba.7z/img_celeba.7z.001
# --
# Path = /content/drive/MyDrive/2022/img_celeba.7z/img_celeba.7z.001
# Type = Split
# Physical Size = 734003200
# Volumes = 14
# Total Physical Size = 10191072466
# ----
# Path = img_celeba.7z
# Size = 10191072466
# --
# Path = img_celeba.7z
# Type = 7z
# Physical Size = 10191072466
# Headers Size = 1963891
# Method = LZMA:24
# Solid = +
# Blocks = 5
#
#  14% 28089 - img_celeba/028090.jpg

# %% [markdown]
# zip data and download locally

# %%
# !zip -r /content/img_celeba.zip /content/

# %%
from google.colab import files
files.download(".zip")
