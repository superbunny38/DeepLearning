# %%
from PIL import Image

# %%
im = Image.open('case1_input.png')
print(im.size)
# Out:
# (680, 512)

# %%
im = Image.open('case1_mask.png')
print(im.size)
# Out:
# (680, 512)

# %%
im = Image.open('ch1.jpg')
print(im.size)
# Out:
# (1440, 960)

# %%
#resize images to use
im.thumbnail((680, 512))
im.save('ch1_input.jpg')

# %%
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
img = load_img("ch1_masked.jpg")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=680x453 at 0x7F0E94475760>

# %%
out_ch = load_img('ch1_final_output.png')
out_ch
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=680x448 at 0x7F0E8C7E29D0>

# %%
import numpy as np
img_arr = img_to_array(img)
np.min(img_arr)
# Out:
# 0.0

# %%
len(img_arr[img_arr == 0.0])
# Out:
# 101

# %%
im = load_img('case1_input.png')
im
# Out:
# <PIL.Image.Image image mode=RGB size=680x512 at 0x7F0E943AB9A0>

# %%
out = load_img('case1_output.png')
out
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=680x512 at 0x7F0E8C7E2D90>

# %%
img_arr2 = img_to_array(im)
img_arr2
# Out:
# array([[[216., 223., 229.],
#         [215., 222., 228.],
#         [214., 221., 227.],
#         ...,
#         [239., 239., 239.],
#         [239., 239., 239.],
#         [239., 239., 239.]],
#
#        [[215., 222., 228.],
#         [214., 221., 227.],
#         [213., 220., 226.],
#         ...,
#         [239., 239., 239.],
#         [239., 239., 239.],
#         [239., 239., 239.]],
#
#        [[213., 220., 226.],
#         [213., 220., 226.],
#         [213., 220., 226.],
#         ...,
#         [239., 239., 239.],
#         [239., 239., 239.],
#         [239., 239., 239.]],
#
#        ...,
#
#        [[ 29.,  41.,  17.],
#         [ 31.,  43.,  19.],
#         [ 32.,  44.,  20.],
#         ...,
#         [ 67.,  50.,  22.],
#         [ 77.,  60.,  32.],
#         [ 79.,  62.,  32.]],
#
#        [[ 18.,  30.,   6.],
#         [ 19.,  31.,   7.],
#         [ 20.,  32.,  10.],
#         ...,
#         [110.,  90.,  65.],
#         [122., 102.,  75.],
# ...

# %%
len(img_arr2[img_arr2 == 0.0])
# Out:
# 2104
