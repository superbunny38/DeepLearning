# %%
from PIL import Image
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
import numpy as np

# %% [markdown]
# ## display test image size

# %%
case_img = Image.open("case1_input.png")
case_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=680x512 at 0x7F9B3AE775E0>

# %%
arr_case = img_to_array(case_img)
arr_case
# Out:
# array([[[216., 223., 229., 255.],
#         [215., 222., 228., 255.],
#         [214., 221., 227., 255.],
#         ...,
#         [239., 239., 239., 255.],
#         [239., 239., 239., 255.],
#         [239., 239., 239., 255.]],
#
#        [[215., 222., 228., 255.],
#         [214., 221., 227., 255.],
#         [213., 220., 226., 255.],
#         ...,
#         [239., 239., 239., 255.],
#         [239., 239., 239., 255.],
#         [239., 239., 239., 255.]],
#
#        [[213., 220., 226., 255.],
#         [213., 220., 226., 255.],
#         [213., 220., 226., 255.],
#         ...,
#         [239., 239., 239., 255.],
#         [239., 239., 239., 255.],
#         [239., 239., 239., 255.]],
#
#        ...,
#
#        [[ 29.,  41.,  17., 255.],
#         [ 31.,  43.,  19., 255.],
#         [ 32.,  44.,  20., 255.],
#         ...,
#         [ 67.,  50.,  22., 255.],
#         [ 77.,  60.,  32., 255.],
#         [ 79.,  62.,  32., 255.]],
#
#        [[ 18.,  30.,   6., 255.],
# ...

# %% [markdown]
# ## CMYK image

# %%
arr_case.shape
# Out:
# (512, 680, 4)

# %%
arr_case[0]
# Out:
# array([[216., 223., 229., 255.],
#        [215., 222., 228., 255.],
#        [214., 221., 227., 255.],
#        ...,
#        [239., 239., 239., 255.],
#        [239., 239., 239., 255.],
#        [239., 239., 239., 255.]], dtype=float32)

# %%
len(arr_case[0][0])
# Out:
# 4

# %%
arr_case[0][0]
# Out:
# array([216., 223., 229., 255.], dtype=float32)

# %% [markdown]
# input image

# %%
im = Image.open('mouth.jpg')

# %%
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=511x505 at 0x7F9B3B9A0250>

# %%
if im.mode == 'RGB':
    print("rgb image data")
    cmyk_image = im.convert('CMYK')
# Out:
# rgb image data

# %%
cmyk_image
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1228     try:
# -> 1229         rawmode, mode = _OUTMODES[mode]
#    1230     except KeyError as e:
#
# KeyError: 'CMYK'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/PIL/Image.py in _repr_png_(self)
#     678         try:
# --> 679             self.save(b, "PNG")
#     680         except Exception as e:
#
# ~/anaconda3/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2239         try:
# -> 2240             save_handler(self, fp, filename)
#    2241         finally:
#
# ...

# %% [markdown]
# mask image

# %%
array_img = img_to_array(im)

# %%
array_img.shape#rgb image (needs to change)
# Out:
# (512, 512, 3)

# %% [markdown]
# ## load image as CMYK

# %% [markdown]
# mask the image

# %%
import scipy
scipy.__version__
# Out:
# '1.7.1'

# %%
# or load image with scipy as RGB
import scipy.misc

prop_shaped_img = scipy.misc.imread('00001.png', mode="CMYK")#[:, :, :3]
prop_shaped_img
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_62969/3737384652.py in <module>
#       2 import scipy.misc
#       3
# ----> 4 prop_shaped_img = scipy.misc.imread('00001.png', mode="CMYK")#[:, :, :3]
#       5 prop_shaped_img
#
# AttributeError: module 'scipy.misc' has no attribute 'imread'

# %%
array_img[300:400] = 0.

# %%
mask_img1 = array_to_img(array_img)
mask_img1
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F9B3BA2D4C0>

# %%
from keras.preprocessing.image import save_img
save_img("test_img1.png",mask_img1)

# %% [markdown]
# ## modify to match the size (rgb->4 channels cmyk)

# %%
pwd
# Out:
# '/home/ubuntu/jupyter/Chaeeun/SN_patchGAN/examples/places2'

# %%
modify = Image.open("cmyk_input1.jpg")
modify
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1228     try:
# -> 1229         rawmode, mode = _OUTMODES[mode]
#    1230     except KeyError as e:
#
# KeyError: 'CMYK'
#
# The above exception was the direct cause of the following exception:
#
# OSError                                   Traceback (most recent call last)
# ~/anaconda3/lib/python3.9/site-packages/PIL/Image.py in _repr_png_(self)
#     678         try:
# --> 679             self.save(b, "PNG")
#     680         except Exception as e:
#
# ~/anaconda3/lib/python3.9/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2239         try:
# -> 2240             save_handler(self, fp, filename)
#    2241         finally:
#
# ...

# %%
img_to_array(modify).shape
# Out:
# (453, 680, 3)

# %%
modify.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_62969/1595414399.py in <module>
# ----> 1 modify.shape
#
# ~/anaconda3/lib/python3.9/site-packages/PIL/Image.py in __getattr__(self, name)
#     544             )
#     545             return self._category
# --> 546         raise AttributeError(name)
#     547
#     548     @property
#
# AttributeError: shape

# %%
modify = Image.open("test_img1.png")
modify

# %%
modify_arr = img_to_array(modify)
modify_arr

# %%
modify_arr.shape

# %%
fill = np.full((512,512,1),255.)
fill

# %%
fill.shape

# %%
right_shaped = np.concatenate([modify_arr, fill], -1)
right_shaped

# %%
CYMK = array_to_img(right_shaped)
save_img("cmyk_img1.png",CMYK)

# %%
CYMK

# %% [markdown]
# python test.py --image examples/places2/cmyk_img1.png --mask examples/places2/case1_mask.png --output examples/places2/0214_1.png --checkpoint_dir model_logs/release_places2_256

# %%
Ima

# %% [markdown]
# check other mask data

# %%
im = Image.open('0214_1.png')
im

# %%
mask_arr = img_to_array(im)
mask_arr

# %%
mask_arr.shape

# %%
# %cd jupyter/Chaeeun/SN_patchGAN

# %%
test1 = Image.open("0214_1.png")
test1

# %%
python test.py --image examples/places2/test_img1.png --mask examples/places2/case1_mask.png --output examples/places2/0214_1.png --checkpoint_dir model_logs/release_places2_256
