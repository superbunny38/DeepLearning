# %% [markdown]
# <a href="https://colab.research.google.com/github/superbunny38/DeepLearning/blob/main/pytorch_advanced/MultiClassSemanticSegmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import urllib.request
import zipfile
import tarfile

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Make folders and Data Downloads

# %%
data_dir = "./data/"
if not os.path.exists(data_dir):
    os.mkdir(data_dir)

# %%
weights_dir = "./weights/"
if not os.path.exists(weights_dir):
    os.mkdir(weights_dir)

# %%
url = "http://host.robots.ox.ac.uk/pascal/VOC/voc2012/VOCtrainval_11-May-2012.tar"
target_path = os.path.join(data_dir, "VOCtrainval_11-May-2012.tar") 

if not os.path.exists(target_path):
    urllib.request.urlretrieve(url, target_path)
    tar = tarfile.TarFile(target_path)
    tar.extractall(data_dir) 
    tar.close()

# %% [markdown]
# folder architecture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# locally download weight from https://drive.google.com/open?id=12eN6SpnawYuQmD1k9VgVW3QSgPR6hICc and put the weight in 'weights' folder

# %%
# !cp /content/drive/MyDrive/2022/LungSegmentation/pspnet50_ADE20K.pth /content/weights
